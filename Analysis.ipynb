# %%
import numpy as np
import pandas as pd
from scipy.spatial import Voronoi, voronoi_plot_2d
import matplotlib.pyplot as plt
import geopandas
from cartopy import crs as ccrs, feature as cfeature

# %%
df = geopandas.read_file('Stop_data.csv')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/admin/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     695     """A pprint that just redirects to the normal repr function."""
#     696     # Find newlines and replace them with p.break_()
# --> 697     output = repr(obj)
#     698     for idx,output_line in enumerate(output.splitlines()):
#     699         if idx:
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __repr__(self)
#     653             max_cols=max_cols,
#     654             line_width=width,
# --> 655             show_dimensions=show_dimensions,
#     656         )
#     657
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width)
#     759             line_width=line_width,
#     760         )
# --> 761         formatter.to_string()
#     762
#     763         if buf is None:
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_string(self)
#     686         else:
#     687
# --> 688             strcols = self._to_str_columns()
#     689             if self.line_width is None:  # no need to wrap around just print
#     690                 # the whole frame
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     624                     self.col_space or 0, *(self.adj.len(x) for x in cheader)
#     625                 )
# --> 626                 fmt_values = self._format_col(i)
#     627                 fmt_values = _make_fixed_width(
#     628                     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     815             na_rep=self.na_rep,
#     816             space=self.col_space,
# --> 817             decimal=self.decimal,
#     818         )
#     819
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1031     )
#    1032
# -> 1033     return fmt_obj.get_result()
#    1034
#    1035
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in get_result(self)
#    1062
#    1063     def get_result(self):
# -> 1064         fmt_values = self._format_strings()
#    1065         return _make_fixed_width(fmt_values, self.justify)
#    1066
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1328             values = values._values
#    1329
# -> 1330         formatter = values._formatter(boxed=True)
#    1331
#    1332         if is_categorical_dtype(values.dtype):
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/geopandas/array.py in _formatter(self, boxed)
#    1009                 # dummy heuristic based on 10 first geometries that should
#    1010                 # work in most cases
# -> 1011                 xmin, ymin, xmax, ymax = self[~self.isna()][:10].total_bounds
#    1012                 if (
#    1013                     (-180 <= xmin <= 180)
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/geopandas/array.py in total_bounds(self)
#     750         return np.array(
#     751             (
# --> 752                 b[:, 0].min(),  # minx
#     753                 b[:, 1].min(),  # miny
#     754                 b[:, 2].max(),  # maxx
#
# IndexError: too many indices for array
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/admin/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     685                 show_dimensions=show_dimensions,
#     686             )
# --> 687             formatter.to_html(notebook=True)
#     688             return formatter.buf.getvalue()
#     689         else:
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
#     838
#     839         Klass = NotebookFormatter if notebook else HTMLFormatter
# --> 840         html = Klass(self, classes=classes, border=border).render()
#     841         if hasattr(self.buf, "write"):
#     842             buffer_put_lines(self.buf, html)
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in render(self)
#     604         self.write("<div>")
#     605         self.write_style()
# --> 606         super().render()
#     607         self.write("</div>")
#     608         return self.elements
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in render(self)
#     191
#     192     def render(self) -> List[str]:
# --> 193         self._write_table()
#     194
#     195         if self.should_show_dimensions:
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     233             self._write_header(indent + self.indent_delta)
#     234
# --> 235         self._write_body(indent + self.indent_delta)
#     236
#     237         self.write("</table>", indent)
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     379     def _write_body(self, indent: int) -> None:
#     380         self.write("<tbody>", indent)
# --> 381         fmt_values = self._get_formatted_values()
#     382
#     383         # write values
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in _get_formatted_values(self)
#     568
#     569     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 570         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     571
#     572     def _get_columns_formatted_values(self) -> List[str]:
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in <dictcomp>(.0)
#     568
#     569     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 570         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     571
#     572     def _get_columns_formatted_values(self) -> List[str]:
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     815             na_rep=self.na_rep,
#     816             space=self.col_space,
# --> 817             decimal=self.decimal,
#     818         )
#     819
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1031     )
#    1032
# -> 1033     return fmt_obj.get_result()
#    1034
#    1035
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in get_result(self)
#    1062
#    1063     def get_result(self):
# -> 1064         fmt_values = self._format_strings()
#    1065         return _make_fixed_width(fmt_values, self.justify)
#    1066
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1328             values = values._values
#    1329
# -> 1330         formatter = values._formatter(boxed=True)
#    1331
#    1332         if is_categorical_dtype(values.dtype):
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/geopandas/array.py in _formatter(self, boxed)
#    1009                 # dummy heuristic based on 10 first geometries that should
#    1010                 # work in most cases
# -> 1011                 xmin, ymin, xmax, ymax = self[~self.isna()][:10].total_bounds
#    1012                 if (
#    1013                     (-180 <= xmin <= 180)
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/geopandas/array.py in total_bounds(self)
#     750         return np.array(
#     751             (
# --> 752                 b[:, 0].min(),  # minx
#     753                 b[:, 1].min(),  # miny
#     754                 b[:, 2].max(),  # maxx
#
# IndexError: too many indices for array

# %%
points = df[['lats','long']]

# %%
vor = Voronoi(points)

# %%
fig = voronoi_plot_2d(vor)
plt.figure(figsize=(300,300))
plt.show()

# %%
gdf = geopandas.GeoDataFrame(geometry=geopandas.points_from_xy(df['long'],df['lats']))

# %%
crs = ccrs.PlateCarree()

# This can be converted into a `proj4` string/dict compatible with GeoPandas
crs_proj4 = crs.proj4_init
df_ae = df.to_crs(crs_proj4)
df_ae.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-e40e20c1759f> in <module>
#       3 # This can be converted into a `proj4` string/dict compatible with GeoPandas
#       4 crs_proj4 = crs.proj4_init
# ----> 5 df_ae = df.to_crs(crs_proj4)
#       6 df_ae.head()
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_crs'
